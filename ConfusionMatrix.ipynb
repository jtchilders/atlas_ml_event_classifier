# %%
import matplotlib.pyplot as plt
# %matplotlib inline
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

# %%
cm = np.array([[9.73191562e-01,1.13115774e-04,2.66953227e-02],
 [5.69670730e-04,9.24632562e-01,7.47977669e-02],
 [2.42158022e-02,9.26395224e-02,8.83144675e-01]])
classes = ['Z->ee','Z->mumu','Z->tautau']

# %%
fig,ax = plt.subplots(figsize=(15,10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix for Z->ll + 2 jets')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
fmt = '.2f'
thresh = cm.max() / 2.
for i, j in itertools.product(range(x.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             fontsize=40,
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.savefig('zll2jet_confmatrix.png')
